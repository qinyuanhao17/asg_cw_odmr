# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
'''For silicon vacancy cw-ODMR'''
Num = 1001#Number of frequency points
StartFreq = 250 # In MHz
EndFreq = 270 # In MHz
RFLevel = 20.0 # In dBm 
RFTime = 100.0 # In ms
RFFreqOffset = 0.0  # In Hz
RFLevelOffset = 0.0  # In dB

# %%
SN = list(range(2,Num+2,1))
length = len(SN)

freq_float = np.linspace(StartFreq,EndFreq,length)
freq_str = []
for i in range(length):
    item = str(round(freq_float[i],3)) + ' MHz'
    freq_str.append(item)

level_float = SN.copy()
level_str = []
for i in range(length):
    item = str(round(RFLevel,3))+ ' dBm'
    level_str.append(item)

time_float = SN.copy()
time_str = []
for i in range(length):
    item = str(round(RFTime,3)) + ' ms'
    time_str.append(item)

FreqOffset_float = SN.copy()
FreqOffset_str = []
for i in range(length):
    item = str(round(RFFreqOffset,3)) + 'Hz'
    FreqOffset_str.append(item)

LevelOffset_float = SN.copy()
LevelOffset_str = []
for i in range(length):
    item = str(round(RFLevelOffset,3)) + ' dB'
    LevelOffset_str.append(item)

init_csv = pd.DataFrame([np.array([1, '9 kHz', '-110.0 dBm', '500.0 ms', '0.0 Hz', '0.0 dB'])], columns= ['SN', 'Freq', 'Level', 'Time', 'Freq Offset', 'Level Offset'])

RFList = np.array([SN, freq_str,level_str, time_str, LevelOffset_str, FreqOffset_str]).transpose()

RF_CSV = pd.DataFrame(RFList, columns= ['SN', 'Freq', 'Level', 'Time', 'Freq Offset', 'Level Offset'])
RF_CSV[['SN']] = RF_CSV[['SN']].astype(int)
RF_CSV.index += 1
RF_CSV
# Out:
#         SN        Freq     Level      Time Freq Offset Level Offset
# 1        2   250.0 MHz  20.0 dBm  100.0 ms      0.0 dB        0.0Hz
# 2        3  250.02 MHz  20.0 dBm  100.0 ms      0.0 dB        0.0Hz
# 3        4  250.04 MHz  20.0 dBm  100.0 ms      0.0 dB        0.0Hz
# 4        5  250.06 MHz  20.0 dBm  100.0 ms      0.0 dB        0.0Hz
# 5        6  250.08 MHz  20.0 dBm  100.0 ms      0.0 dB        0.0Hz
# ...    ...         ...       ...       ...         ...          ...
# 997    998  269.92 MHz  20.0 dBm  100.0 ms      0.0 dB        0.0Hz
# 998    999  269.94 MHz  20.0 dBm  100.0 ms      0.0 dB        0.0Hz
# 999   1000  269.96 MHz  20.0 dBm  100.0 ms      0.0 dB        0.0Hz
# 1000  1001  269.98 MHz  20.0 dBm  100.0 ms      0.0 dB        0.0Hz
# 1001  1002   270.0 MHz  20.0 dBm  100.0 ms      0.0 dB        0.0Hz
#
# [1001 rows x 6 columns]

# %%
shuffled_rf_csv = RF_CSV.sample(frac = 1)

# %%
shuffled_rf_csv
# Out:
#       SN        Freq     Level      Time Freq Offset Level Offset
# 313  314  256.24 MHz  20.0 dBm  100.0 ms      0.0 dB        0.0Hz
# 843  844  266.84 MHz  20.0 dBm  100.0 ms      0.0 dB        0.0Hz
# 99   100  251.96 MHz  20.0 dBm  100.0 ms      0.0 dB        0.0Hz
# 952  953  269.02 MHz  20.0 dBm  100.0 ms      0.0 dB        0.0Hz
# 816  817   266.3 MHz  20.0 dBm  100.0 ms      0.0 dB        0.0Hz
# ..   ...         ...       ...       ...         ...          ...
# 891  892   267.8 MHz  20.0 dBm  100.0 ms      0.0 dB        0.0Hz
# 900  901  267.98 MHz  20.0 dBm  100.0 ms      0.0 dB        0.0Hz
# 239  240  254.76 MHz  20.0 dBm  100.0 ms      0.0 dB        0.0Hz
# 726  727   264.5 MHz  20.0 dBm  100.0 ms      0.0 dB        0.0Hz
# 554  555  261.06 MHz  20.0 dBm  100.0 ms      0.0 dB        0.0Hz
#
# [1001 rows x 6 columns]

# %%
final_csv = pd.concat([init_csv, shuffled_rf_csv],axis=0)
final_csv.to_csv('sweep_list_analysis.csv')
final_csv.to_csv('sweep_list.csv', index=None)

# %%
final_csv
# Out:
#       SN        Freq       Level      Time Freq Offset Level Offset
# 0      1       9 kHz  -110.0 dBm  500.0 ms      0.0 Hz       0.0 dB
# 313  314  256.24 MHz    20.0 dBm  100.0 ms      0.0 dB        0.0Hz
# 843  844  266.84 MHz    20.0 dBm  100.0 ms      0.0 dB        0.0Hz
# 99   100  251.96 MHz    20.0 dBm  100.0 ms      0.0 dB        0.0Hz
# 952  953  269.02 MHz    20.0 dBm  100.0 ms      0.0 dB        0.0Hz
# ..   ...         ...         ...       ...         ...          ...
# 891  892   267.8 MHz    20.0 dBm  100.0 ms      0.0 dB        0.0Hz
# 900  901  267.98 MHz    20.0 dBm  100.0 ms      0.0 dB        0.0Hz
# 239  240  254.76 MHz    20.0 dBm  100.0 ms      0.0 dB        0.0Hz
# 726  727   264.5 MHz    20.0 dBm  100.0 ms      0.0 dB        0.0Hz
# 554  555  261.06 MHz    20.0 dBm  100.0 ms      0.0 dB        0.0Hz
#
# [1002 rows x 6 columns]
